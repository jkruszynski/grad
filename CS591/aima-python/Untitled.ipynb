# %%
#!/usr/bin/env python

#Author: nhny at hcmut.edu.vn
#Course: AI 2016
#Lab 3
from sys import argv
from time import time

# %%
class Searcher(object):
    """Searcher that manuplate searching process."""

    def __init__(self, start, goal):
        self.start = start
        self.goal = goal

    def print_path(self, state):
        path = []
        while state:
            path.append(state)
            state = state.prev
        path.reverse()
        print("\n-->\n".join([str(state) for state in path]))

    def dfs(self, depth = 100):
        stack = [self.start]
        visited = set()
        found = False

        while stack:
            state = stack.pop()

            if state == self.goal:
                found = state
                break

            if state in visited or state.step > depth:
                continue

            visited.add(state)

            for s in state.next():
                stack.append(s)

        if found:
            self.print_path(found)
            print ("Find solution")
        else:
            print("No solution found")

    def bfs(self, depth = 50):
        """Run Breadth-first search."""
        #TODO: Implement breadth first search
        queue = [self.start]
        visited = set()
        found = False

        while queue:
            state = queue.pop()

            if state == self.goal:
                found = state
                break

            if state in visited or state.step > depth:
                continue

            visited.add(state)

            for s in state.next():
                queue.insert(0, s)

        if found:
            self.print_path(found)
            print ("Find solution")
        else:
            print("No solution found")

    def steepest_ascent_hill_climbing(self):
        """Run steepest ascent hill climbing search."""
        #TODO Implement hill climbing.
        stack = [self.start]

        while stack:
            state = stack.pop()
            if state == self.goal:
                self.print_path(state)
                print ("Find solution")
                break

            h_val = state.manhattan_distance() + state.hamming_distance()
            next_state = False
            for s in state.next():
                h_val_next = s.manhattan_distance() + s.hamming_distance()
                if h_val_next < h_val:
                    next_state = s
                    h_val = h_val_next

            if next_state: 
                stack.append(next_state)
            else:
                self.print_path(state)
                print ("Cannot find solution")


    # I don't know this function
    def hill_climbing(self):
        """Run hill climbing search."""
        #TODO Implement hill climbing.
        stack = [self.start]

        while stack:
            state = stack.pop()
            if state == self.goal:
                self.print_path(state)
                print( "Find solution")
                break

            h_val = state.manhattan_distance() + state.hamming_distance()
            next_state = False
            for s in state.next():
                h_val_next = s.manhattan_distance() + s.hamming_distance()
                if h_val_next < h_val:
                    next_state = s
                    h_val = h_val_next
                    stack.append(next_state)
                    break

            if not next_state:
                self.print_path(state)
                print ("Cannot find solution")
            
    def astar(self, depth = 75):
        """Run A* search."""
        #TODO: Implement a star search.
        priotity_queue = PriorityQueue()
        h_val = self.start.manhattan_distance() + self.start.hamming_distance()
        # g_val always is start.step
        f_val = h_val + self.start.step
        priotity_queue.push(self.start, f_val)
        visited = set()
        found = False

        while not priotity_queue.isEmpty():
            state = priotity_queue.pop()

            if state == self.goal:
                found = state
                break

            if state in visited or state.step > depth:
                continue

            visited.add(state)

            for s in state.next():
                h_val_s = s.manhattan_distance() + s.hamming_distance()
                f_val_s = h_val_s + s.step
                priotity_queue.push(s, f_val_s)

        if found:
            self.print_path(found)
            print("Find solution")
        else:
            print("No solution found")

# %%
#Author: nhny at hcmut.edu.vn
#Course: AI 2016
#Lab 3
# DFS, BFS, Hill Climbing, A-Star with heuristics manhattan distance and hamming distance. 

import heapq

class Node(object):
    """
    Represent state of board in 8 puzzle problem.
    """
    n = 0

    def __init__(self, board, prev_state = None):
        assert len(board) == 9

        self.board = board[:];
        self.prev = prev_state
        self.step = 0
        Node.n += 1

        if self.prev:
            self.step = self.prev.step + 1 

    def __eq__(self, other):
        """Check wether two state is equal."""
        return self.board == other.board

    def __hash__(self):
        """Return hash code of object.
        Used for comparing elements in set
        """
        h = [0, 0, 0]
        h[0] = self.board[0] << 6 | self.board[1] << 3 | self.board[2]
        h[1] = self.board[3] << 6 | self.board[4] << 3 | self.board[5]
        h[2] = self.board[6] << 6 | self.board[7] << 3 | self.board[8]

        h_val = 0
        for h_i in h:
            h_val = h_val * 31 + h_i

        return h_val

    def __str__(self):
        string_list = [str(i) for i in self.board]
        sub_list = (string_list[:3], string_list[3:6], string_list[6:])
        return "\n".join([" ".join(l) for l in sub_list])

    def manhattan_distance(self):
        """Return Manhattan distance of state."""
        #TODO: return Manhattan distance
        distance = 0
        goal = [1,2,3,4,5,6,7,8,0]
        for i in range(1,9):
            xs, ys = self.__i2pos(self.board.index(i))
            xg, yg = self.__i2pos(goal.index(i))
            distance += abs(xs-xg) + abs(ys-yg)
        return distance

    def manhattan_score(self):
        """Return Manhattan score of state."""
        #TODO: return Manhattan score of state
        return 0

    def hamming_distance(self):
        """Return Hamming distance of state."""
        #TODO: return Hamming distance
        distance = 0
        goal = [1,2,3,4,5,6,7,8,0]
        for i in range(9):
            if goal[i] != self.board[i]: distance += 1
        return distance

    def hamming_score(self):
        """Return Hamming distance score of state."""
        #TODO return Hamming score of state
        return 0

    def next(self):
        """Return next states from this state."""
        next_moves = []
        i = self.board.index(0)

        next_moves = (self.move_up(i), self.move_down(i), self.move_left(i), self.move_right(i))

        return [s for s in next_moves if s]

    def move_right(self, i):
        x, y = self.__i2pos(i)
        if y < 2:
            right_state = Node(self.board, self)
            right = self.__pos2i(x, y+1)
            right_state.__swap(i, right)
            return right_state

    def move_left(self, i):
        x, y = self.__i2pos(i)
        if y > 0:
            left_state = Node(self.board, self)
            left = self.__pos2i(x, y - 1)
            left_state.__swap(i, left)
            return left_state

    def move_up(self, i):
        x, y = self.__i2pos(i)
        if x > 0:
            up_state = Node(self.board, self)
            up = self.__pos2i(x - 1, y)
            up_state.__swap(i, up)
            return up_state

    def move_down(self, i):
        x, y = self.__i2pos(i)
        if x < 2:
            down_state = Node(self.board, self)
            down = self.__pos2i(x + 1, y)
            down_state.__swap(i, down)
            return down_state

    def __swap(self, i, j):
        self.board[j], self.board[i] = self.board[i], self.board[j]

    def __i2pos(self, index):
        return (int(index / 3), index % 3)

    def __pos2i(self, x, y):
        return x * 3 + y


class PriorityQueue:
    def  __init__(self):
        self.heap = []
        self.count = 0

    def push(self, item, priority):
        # FIXME: restored old behaviour to check against old results better
        # FIXED: restored to stable behaviour
        entry = (priority, self.count, item)
        # entry = (priority, item)
        heapq.heappush(self.heap, entry)
        self.count += 1

    def pop(self):
        (_, _, item) = heapq.heappop(self.heap)
        #  (_, item) = heapq.heappop(self.heap)
        return item

    def isEmpty(self):
        return len(self.heap) == 0

# %%
import random

base = [1,2,3,4,5,6,7,8,0]

for i in range(100):
    random.shuffle(base)
    print(base)
    print("Search for solution\n")
    start = Node(base)
    goal = Node([1,2,3,4,5,6,7,8,0])

    #print start.hamming_distance()
    #print start.manhattan_distance()

    search = Searcher(start, goal)

    start_time = time()

    search.hill_climbing()

    end_time = time()
    elapsed = end_time - start_time
    print ("Search time: %s" % elapsed)
    print ("Number of initialized node: %d" % Node.n)
# Out:
# [8, 6, 3, 0, 5, 7, 2, 1, 4]
# Search for solution
#
# 8 6 3
# 0 5 7
# 2 1 4
# -->
# 0 6 3
# 8 5 7
# 2 1 4
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 324
# [8, 5, 7, 6, 4, 3, 2, 1, 0]
# Search for solution
#
# 8 5 7
# 6 4 3
# 2 1 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 328
# [5, 7, 1, 8, 0, 4, 2, 3, 6]
# Search for solution
#
# 5 7 1
# 8 0 4
# 2 3 6
# -->
# 5 0 1
# 8 7 4
# 2 3 6
# -->
# 0 5 1
# 8 7 4
# 2 3 6
# Cannot find solution
# Search time: 0.0010020732879638672
# Number of initialized node: 339
# [2, 1, 6, 7, 3, 4, 8, 5, 0]
# Search for solution
#
# 2 1 6
# 7 3 4
# 8 5 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 343
# [8, 0, 1, 7, 5, 4, 3, 6, 2]
# Search for solution
#
# 8 0 1
# 7 5 4
# 3 6 2
# -->
# 0 8 1
# 7 5 4
# 3 6 2
# Cannot find solution
# Search time: 0.0010004043579101562
# Number of initialized node: 350
# [6, 1, 2, 4, 8, 3, 7, 5, 0]
# Search for solution
#
# 6 1 2
# 4 8 3
# 7 5 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 354
# [6, 7, 2, 8, 3, 0, 4, 5, 1]
# Search for solution
#
# 6 7 2
# 8 3 0
# 4 5 1
# -->
# 6 7 2
# 8 3 1
# 4 5 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 361
# [7, 2, 6, 3, 8, 4, 5, 0, 1]
# Search for solution
#
# 7 2 6
# 3 8 4
# 5 0 1
# -->
# 7 2 6
# 3 0 4
# 5 8 1
# -->
# 7 2 6
# 0 3 4
# 5 8 1
# -->
# 0 2 6
# 7 3 4
# 5 8 1
# Cannot find solution
# Search time: 0.0009992122650146484
# Number of initialized node: 375
# [5, 8, 1, 6, 4, 7, 2, 0, 3]
# Search for solution
#
# 5 8 1
# 6 4 7
# 2 0 3
# -->
# 5 8 1
# 6 4 7
# 0 2 3
# Cannot find solution
# Search time: 0.00099945068359375
# Number of initialized node: 382
# [0, 1, 6, 8, 5, 3, 7, 4, 2]
# Search for solution
#
# 0 1 6
# 8 5 3
# 7 4 2
# -->
# 1 0 6
# 8 5 3
# 7 4 2
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 389
# [5, 6, 0, 4, 7, 1, 3, 8, 2]
# Search for solution
#
# 5 6 0
# 4 7 1
# 3 8 2
# -->
# 5 6 1
# 4 7 0
# 3 8 2
# -->
# 5 6 1
# 4 7 2
# 3 8 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 398
# [2, 8, 5, 7, 4, 6, 0, 3, 1]
# Search for solution
#
# 2 8 5
# 7 4 6
# 0 3 1
# -->
# 2 8 5
# 0 4 6
# 7 3 1
# -->
# 2 8 5
# 4 0 6
# 7 3 1
# -->
# 2 0 5
# 4 8 6
# 7 3 1
# -->
# 0 2 5
# 4 8 6
# 7 3 1
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 414
# [5, 8, 6, 3, 4, 7, 2, 0, 1]
# Search for solution
#
# 5 8 6
# 3 4 7
# 2 0 1
# -->
# 5 8 6
# 3 4 7
# 0 2 1
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 421
# [0, 7, 3, 8, 6, 1, 2, 5, 4]
# Search for solution
#
# 0 7 3
# 8 6 1
# 2 5 4
# -->
# 7 0 3
# 8 6 1
# 2 5 4
# Cannot find solution
# Search time: 0.0010006427764892578
# Number of initialized node: 428
# [5, 2, 4, 0, 8, 1, 3, 6, 7]
# Search for solution
#
# 5 2 4
# 0 8 1
# 3 6 7
# -->
# 0 2 4
# 5 8 1
# 3 6 7
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 435
# [8, 7, 3, 5, 6, 1, 0, 2, 4]
# Search for solution
#
# 8 7 3
# 5 6 1
# 0 2 4
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 439
# [4, 2, 6, 5, 0, 1, 7, 3, 8]
# Search for solution
#
# 4 2 6
# 5 0 1
# 7 3 8
# -->
# 4 2 6
# 5 3 1
# 7 0 8
# -->
# 4 2 6
# 5 3 1
# 7 8 0
# Cannot find solution
# Search time: 0.001001596450805664
# Number of initialized node: 450
# [8, 7, 4, 1, 5, 6, 3, 2, 0]
# Search for solution
#
# 8 7 4
# 1 5 6
# 3 2 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 454
# [1, 2, 7, 0, 4, 8, 5, 3, 6]
# Search for solution
#
# 1 2 7
# 0 4 8
# 5 3 6
# -->
# 1 2 7
# 5 4 8
# 0 3 6
# Cannot find solution
# Search time: 0.0010077953338623047
# Number of initialized node: 461
# [6, 8, 2, 3, 4, 0, 1, 5, 7]
# Search for solution
#
# 6 8 2
# 3 4 0
# 1 5 7
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 466
# [6, 7, 0, 2, 5, 1, 8, 4, 3]
# Search for solution
#
# 6 7 0
# 2 5 1
# 8 4 3
# -->
# 6 7 1
# 2 5 0
# 8 4 3
# -->
# 6 7 1
# 2 5 3
# 8 4 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 475
# [5, 8, 3, 4, 6, 2, 7, 0, 1]
# Search for solution
#
# 5 8 3
# 4 6 2
# 7 0 1
# -->
# 5 8 3
# 4 6 2
# 7 1 0
# Cannot find solution
# Search time: 0.0010004043579101562
# Number of initialized node: 482
# [8, 0, 2, 5, 1, 6, 4, 7, 3]
# Search for solution
#
# 8 0 2
# 5 1 6
# 4 7 3
# -->
# 8 1 2
# 5 0 6
# 4 7 3
# -->
# 8 1 2
# 0 5 6
# 4 7 3
# -->
# 0 1 2
# 8 5 6
# 4 7 3
# -->
# 1 0 2
# 8 5 6
# 4 7 3
# -->
# 1 2 0
# 8 5 6
# 4 7 3
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 501
# [7, 2, 8, 1, 4, 3, 5, 6, 0]
# Search for solution
#
# 7 2 8
# 1 4 3
# 5 6 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 505
# [2, 8, 3, 4, 5, 6, 0, 7, 1]
# Search for solution
#
# 2 8 3
# 4 5 6
# 0 7 1
# -->
# 2 8 3
# 4 5 6
# 7 0 1
# -->
# 2 8 3
# 4 5 6
# 7 1 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 514
# [7, 2, 3, 6, 5, 1, 4, 8, 0]
# Search for solution
#
# 7 2 3
# 6 5 1
# 4 8 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 518
# [6, 5, 1, 0, 7, 4, 8, 2, 3]
# Search for solution
#
# 6 5 1
# 0 7 4
# 8 2 3
# -->
# 0 5 1
# 6 7 4
# 8 2 3
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 525
# [6, 1, 8, 7, 5, 3, 4, 2, 0]
# Search for solution
#
# 6 1 8
# 7 5 3
# 4 2 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 529
# [4, 8, 6, 2, 0, 1, 3, 7, 5]
# Search for solution
#
# 4 8 6
# 2 0 1
# 3 7 5
# -->
# 4 0 6
# 2 8 1
# 3 7 5
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 538
# [1, 6, 5, 0, 2, 3, 7, 8, 4]
# Search for solution
#
# 1 6 5
# 0 2 3
# 7 8 4
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 543
# [1, 8, 5, 6, 0, 4, 2, 7, 3]
# Search for solution
#
# 1 8 5
# 6 0 4
# 2 7 3
# -->
# 1 0 5
# 6 8 4
# 2 7 3
# -->
# 1 5 0
# 6 8 4
# 2 7 3
# Cannot find solution
# Search time: 0.0009996891021728516
# Number of initialized node: 554
# [2, 6, 0, 1, 5, 8, 3, 4, 7]
# Search for solution
#
# 2 6 0
# 1 5 8
# 3 4 7
# -->
# 2 0 6
# 1 5 8
# 3 4 7
# -->
# 0 2 6
# 1 5 8
# 3 4 7
# -->
# 1 2 6
# 0 5 8
# 3 4 7
# -->
# 1 2 6
# 3 5 8
# 0 4 7
# -->
# 1 2 6
# 3 5 8
# 4 0 7
# -->
# 1 2 6
# 3 5 8
# 4 7 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 573
# [3, 7, 6, 8, 4, 2, 0, 5, 1]
# Search for solution
#
# 3 7 6
# 8 4 2
# 0 5 1
# -->
# 3 7 6
# 0 4 2
# 8 5 1
# -->
# 3 7 6
# 4 0 2
# 8 5 1
# -->
# 3 0 6
# 4 7 2
# 8 5 1
# -->
# 0 3 6
# 4 7 2
# 8 5 1
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 589
# [0, 4, 3, 8, 7, 5, 6, 1, 2]
# Search for solution
#
# 0 4 3
# 8 7 5
# 6 1 2
# -->
# 4 0 3
# 8 7 5
# 6 1 2
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 596
# [0, 3, 1, 6, 4, 2, 8, 7, 5]
# Search for solution
#
# 0 3 1
# 6 4 2
# 8 7 5
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 600
# [6, 0, 7, 5, 1, 4, 2, 3, 8]
# Search for solution
#
# 6 0 7
# 5 1 4
# 2 3 8
# -->
# 6 1 7
# 5 0 4
# 2 3 8
# -->
# 6 1 7
# 5 3 4
# 2 0 8
# -->
# 6 1 7
# 5 3 4
# 0 2 8
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 614
# [8, 6, 4, 2, 0, 3, 7, 1, 5]
# Search for solution
#
# 8 6 4
# 2 0 3
# 7 1 5
# -->
# 8 0 4
# 2 6 3
# 7 1 5
# -->
# 0 8 4
# 2 6 3
# 7 1 5
# -->
# 2 8 4
# 0 6 3
# 7 1 5
# Cannot find solution
# Search time: 0.001001596450805664
# Number of initialized node: 628
# [7, 3, 4, 0, 6, 5, 1, 2, 8]
# Search for solution
#
# 7 3 4
# 0 6 5
# 1 2 8
# -->
# 0 3 4
# 7 6 5
# 1 2 8
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 635
# [2, 4, 5, 1, 3, 6, 7, 8, 0]
# Search for solution
#
# 2 4 5
# 1 3 6
# 7 8 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 639
# [5, 0, 4, 3, 6, 7, 8, 1, 2]
# Search for solution
#
# 5 0 4
# 3 6 7
# 8 1 2
# -->
# 0 5 4
# 3 6 7
# 8 1 2
# -->
# 3 5 4
# 0 6 7
# 8 1 2
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 649
# [3, 2, 1, 0, 6, 4, 5, 7, 8]
# Search for solution
#
# 3 2 1
# 0 6 4
# 5 7 8
# -->
# 3 2 1
# 5 6 4
# 0 7 8
# -->
# 3 2 1
# 5 6 4
# 7 0 8
# -->
# 3 2 1
# 5 6 4
# 7 8 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 661
# [8, 3, 6, 0, 7, 2, 5, 1, 4]
# Search for solution
#
# 8 3 6
# 0 7 2
# 5 1 4
# -->
# 0 3 6
# 8 7 2
# 5 1 4
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 668
# [1, 7, 8, 5, 3, 6, 0, 4, 2]
# Search for solution
#
# 1 7 8
# 5 3 6
# 0 4 2
# -->
# 1 7 8
# 5 3 6
# 4 0 2
# -->
# 1 7 8
# 5 3 6
# 4 2 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 677
# [0, 3, 8, 4, 5, 6, 1, 7, 2]
# Search for solution
#
# 0 3 8
# 4 5 6
# 1 7 2
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 681
# [0, 1, 2, 5, 6, 4, 3, 8, 7]
# Search for solution
#
# 0 1 2
# 5 6 4
# 3 8 7
# -->
# 1 0 2
# 5 6 4
# 3 8 7
# -->
# 1 2 0
# 5 6 4
# 3 8 7
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 690
# [2, 3, 1, 8, 0, 7, 5, 4, 6]
# Search for solution
#
# 2 3 1
# 8 0 7
# 5 4 6
# -->
# 2 3 1
# 8 4 7
# 5 0 6
# -->
# 2 3 1
# 8 4 7
# 0 5 6
# -->
# 2 3 1
# 0 4 7
# 8 5 6
# -->
# 2 3 1
# 4 0 7
# 8 5 6
# -->
# 2 3 1
# 4 5 7
# 8 0 6
# -->
# 2 3 1
# 4 5 7
# 0 8 6
# Cannot find solution
# Search time: 0.0009920597076416016
# Number of initialized node: 713
# [6, 0, 4, 5, 7, 1, 8, 2, 3]
# Search for solution
#
# 6 0 4
# 5 7 1
# 8 2 3
# -->
# 0 6 4
# 5 7 1
# 8 2 3
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 720
# [8, 5, 2, 7, 4, 3, 1, 0, 6]
# Search for solution
#
# 8 5 2
# 7 4 3
# 1 0 6
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 725
# [0, 6, 3, 5, 8, 4, 1, 2, 7]
# Search for solution
#
# 0 6 3
# 5 8 4
# 1 2 7
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 729
# [4, 8, 7, 2, 1, 5, 6, 3, 0]
# Search for solution
#
# 4 8 7
# 2 1 5
# 6 3 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 733
# [7, 5, 8, 6, 1, 0, 4, 3, 2]
# Search for solution
#
# 7 5 8
# 6 1 0
# 4 3 2
# -->
# 7 5 0
# 6 1 8
# 4 3 2
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 740
# [2, 0, 5, 3, 6, 8, 1, 7, 4]
# Search for solution
#
# 2 0 5
# 3 6 8
# 1 7 4
# -->
# 0 2 5
# 3 6 8
# 1 7 4
# -->
# 3 2 5
# 0 6 8
# 1 7 4
# -->
# 3 2 5
# 1 6 8
# 0 7 4
# -->
# 3 2 5
# 1 6 8
# 7 0 4
# -->
# 3 2 5
# 1 6 8
# 7 4 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 757
# [3, 8, 0, 1, 5, 7, 2, 4, 6]
# Search for solution
#
# 3 8 0
# 1 5 7
# 2 4 6
# Cannot find solution
# Search time: 0.001001119613647461
# Number of initialized node: 761
# [8, 3, 0, 7, 1, 4, 5, 2, 6]
# Search for solution
#
# 8 3 0
# 7 1 4
# 5 2 6
# -->
# 8 0 3
# 7 1 4
# 5 2 6
# -->
# 8 1 3
# 7 0 4
# 5 2 6
# -->
# 8 1 3
# 7 2 4
# 5 0 6
# -->
# 8 1 3
# 7 2 4
# 0 5 6
# -->
# 8 1 3
# 0 2 4
# 7 5 6
# -->
# 0 1 3
# 8 2 4
# 7 5 6
# -->
# 1 0 3
# 8 2 4
# 7 5 6
# -->
# 1 2 3
# 8 0 4
# 7 5 6
# -->
# 1 2 3
# 8 5 4
# 7 0 6
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 792
# [7, 4, 8, 2, 1, 5, 6, 3, 0]
# Search for solution
#
# 7 4 8
# 2 1 5
# 6 3 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 796
# [6, 2, 4, 5, 0, 8, 7, 3, 1]
# Search for solution
#
# 6 2 4
# 5 0 8
# 7 3 1
# -->
# 6 2 4
# 5 3 8
# 7 0 1
# -->
# 6 2 4
# 5 3 8
# 7 1 0
# Cannot find solution
# Search time: 0.0009980201721191406
# Number of initialized node: 807
# [5, 0, 8, 7, 6, 4, 3, 2, 1]
# Search for solution
#
# 5 0 8
# 7 6 4
# 3 2 1
# -->
# 0 5 8
# 7 6 4
# 3 2 1
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 814
# [1, 0, 5, 2, 8, 6, 4, 3, 7]
# Search for solution
#
# 1 0 5
# 2 8 6
# 4 3 7
# -->
# 1 5 0
# 2 8 6
# 4 3 7
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 821
# [7, 1, 4, 5, 3, 6, 2, 0, 8]
# Search for solution
#
# 7 1 4
# 5 3 6
# 2 0 8
# -->
# 7 1 4
# 5 3 6
# 0 2 8
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 828
# [3, 0, 8, 4, 7, 2, 5, 6, 1]
# Search for solution
#
# 3 0 8
# 4 7 2
# 5 6 1
# -->
# 0 3 8
# 4 7 2
# 5 6 1
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 835
# [6, 5, 3, 4, 7, 2, 8, 0, 1]
# Search for solution
#
# 6 5 3
# 4 7 2
# 8 0 1
# -->
# 6 5 3
# 4 0 2
# 8 7 1
# -->
# 6 0 3
# 4 5 2
# 8 7 1
# -->
# 0 6 3
# 4 5 2
# 8 7 1
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 849
# [3, 7, 8, 5, 4, 0, 2, 1, 6]
# Search for solution
#
# 3 7 8
# 5 4 0
# 2 1 6
# -->
# 3 7 0
# 5 4 8
# 2 1 6
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 856
# [1, 2, 3, 5, 4, 6, 0, 8, 7]
# Search for solution
#
# 1 2 3
# 5 4 6
# 0 8 7
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 860
# [4, 0, 5, 7, 6, 3, 1, 2, 8]
# Search for solution
#
# 4 0 5
# 7 6 3
# 1 2 8
# -->
# 4 5 0
# 7 6 3
# 1 2 8
# -->
# 4 5 3
# 7 6 0
# 1 2 8
# -->
# 4 5 3
# 7 0 6
# 1 2 8
# -->
# 4 0 3
# 7 5 6
# 1 2 8
# Cannot find solution
# Search time: 0.0009999275207519531
# Number of initialized node: 877
# [5, 8, 0, 1, 3, 7, 6, 2, 4]
# Search for solution
#
# 5 8 0
# 1 3 7
# 6 2 4
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 881
# [3, 5, 1, 8, 2, 7, 6, 0, 4]
# Search for solution
#
# 3 5 1
# 8 2 7
# 6 0 4
# -->
# 3 5 1
# 8 2 7
# 0 6 4
# -->
# 3 5 1
# 0 2 7
# 8 6 4
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 891
# [0, 4, 2, 3, 7, 6, 8, 1, 5]
# Search for solution
#
# 0 4 2
# 3 7 6
# 8 1 5
# -->
# 3 4 2
# 0 7 6
# 8 1 5
# -->
# 3 4 2
# 7 0 6
# 8 1 5
# -->
# 3 0 2
# 7 4 6
# 8 1 5
# -->
# 0 3 2
# 7 4 6
# 8 1 5
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 907
# [4, 6, 0, 8, 2, 3, 1, 5, 7]
# Search for solution
#
# 4 6 0
# 8 2 3
# 1 5 7
# -->
# 4 6 3
# 8 2 0
# 1 5 7
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 914
# [1, 6, 7, 0, 2, 5, 8, 3, 4]
# Search for solution
#
# 1 6 7
# 0 2 5
# 8 3 4
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 919
# [6, 0, 5, 7, 3, 2, 1, 8, 4]
# Search for solution
#
# 6 0 5
# 7 3 2
# 1 8 4
# -->
# 6 3 5
# 7 0 2
# 1 8 4
# -->
# 6 3 5
# 7 2 0
# 1 8 4
# -->
# 6 3 0
# 7 2 5
# 1 8 4
# -->
# 6 0 3
# 7 2 5
# 1 8 4
# -->
# 6 2 3
# 7 0 5
# 1 8 4
# -->
# 6 2 3
# 7 5 0
# 1 8 4
# -->
# 6 2 3
# 7 5 4
# 1 8 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 945
# [6, 5, 1, 7, 0, 8, 3, 2, 4]
# Search for solution
#
# 6 5 1
# 7 0 8
# 3 2 4
# -->
# 6 0 1
# 7 5 8
# 3 2 4
# -->
# 0 6 1
# 7 5 8
# 3 2 4
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 956
# [0, 6, 8, 2, 7, 5, 3, 4, 1]
# Search for solution
#
# 0 6 8
# 2 7 5
# 3 4 1
# -->
# 2 6 8
# 0 7 5
# 3 4 1
# -->
# 2 6 8
# 3 7 5
# 0 4 1
# -->
# 2 6 8
# 3 7 5
# 4 0 1
# -->
# 2 6 8
# 3 0 5
# 4 7 1
# -->
# 2 0 8
# 3 6 5
# 4 7 1
# -->
# 0 2 8
# 3 6 5
# 4 7 1
# -->
# 3 2 8
# 0 6 5
# 4 7 1
# -->
# 3 2 8
# 4 6 5
# 0 7 1
# -->
# 3 2 8
# 4 6 5
# 7 0 1
# -->
# 3 2 8
# 4 6 5
# 7 1 0
# Cannot find solution
# Search time: 0.0010004043579101562
# Number of initialized node: 987
# [1, 0, 5, 8, 6, 2, 3, 7, 4]
# Search for solution
#
# 1 0 5
# 8 6 2
# 3 7 4
# -->
# 1 5 0
# 8 6 2
# 3 7 4
# -->
# 1 5 2
# 8 6 0
# 3 7 4
# -->
# 1 5 2
# 8 6 4
# 3 7 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 999
# [7, 6, 1, 2, 3, 8, 0, 5, 4]
# Search for solution
#
# 7 6 1
# 2 3 8
# 0 5 4
# Cannot find solution
# Search time: 0.0010013580322265625
# Number of initialized node: 1003
# [1, 6, 2, 7, 5, 8, 4, 3, 0]
# Search for solution
#
# 1 6 2
# 7 5 8
# 4 3 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 1007
# [5, 8, 0, 1, 6, 3, 2, 7, 4]
# Search for solution
#
# 5 8 0
# 1 6 3
# 2 7 4
# -->
# 5 8 3
# 1 6 0
# 2 7 4
# -->
# 5 8 3
# 1 6 4
# 2 7 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 1016
# [0, 7, 8, 3, 4, 5, 6, 1, 2]
# Search for solution
#
# 0 7 8
# 3 4 5
# 6 1 2
# -->
# 3 7 8
# 0 4 5
# 6 1 2
# -->
# 3 7 8
# 6 4 5
# 0 1 2
# -->
# 3 7 8
# 6 4 5
# 1 0 2
# -->
# 3 7 8
# 6 4 5
# 1 2 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 1030
# [5, 0, 6, 1, 8, 7, 3, 4, 2]
# Search for solution
#
# 5 0 6
# 1 8 7
# 3 4 2
# -->
# 0 5 6
# 1 8 7
# 3 4 2
# -->
# 1 5 6
# 0 8 7
# 3 4 2
# -->
# 1 5 6
# 3 8 7
# 0 4 2
# -->
# 1 5 6
# 3 8 7
# 4 0 2
# -->
# 1 5 6
# 3 0 7
# 4 8 2
# -->
# 1 0 6
# 3 5 7
# 4 8 2
# Cannot find solution
# Search time: 0.0010039806365966797
# Number of initialized node: 1052
# [4, 3, 0, 6, 7, 8, 5, 1, 2]
# Search for solution
#
# 4 3 0
# 6 7 8
# 5 1 2
# -->
# 4 0 3
# 6 7 8
# 5 1 2
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 1059
# [3, 5, 2, 0, 8, 7, 1, 6, 4]
# Search for solution
#
# 3 5 2
# 0 8 7
# 1 6 4
# -->
# 3 5 2
# 1 8 7
# 0 6 4
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 1066
# [6, 5, 1, 2, 3, 4, 0, 8, 7]
# Search for solution
#
# 6 5 1
# 2 3 4
# 0 8 7
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 1070
# [8, 2, 4, 1, 3, 6, 7, 5, 0]
# Search for solution
#
# 8 2 4
# 1 3 6
# 7 5 0
# Cannot find solution
# Search time: 0.0009975433349609375
# Number of initialized node: 1074
# [2, 4, 3, 1, 0, 8, 6, 5, 7]
# Search for solution
#
# 2 4 3
# 1 0 8
# 6 5 7
# -->
# 2 0 3
# 1 4 8
# 6 5 7
# -->
# 0 2 3
# 1 4 8
# 6 5 7
# -->
# 1 2 3
# 0 4 8
# 6 5 7
# -->
# 1 2 3
# 6 4 8
# 0 5 7
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 1090
# [2, 6, 4, 3, 8, 7, 0, 5, 1]
# Search for solution
#
# 2 6 4
# 3 8 7
# 0 5 1
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 1094
# [1, 6, 3, 2, 7, 4, 8, 0, 5]
# Search for solution
#
# 1 6 3
# 2 7 4
# 8 0 5
# -->
# 1 6 3
# 2 0 4
# 8 7 5
# -->
# 1 0 3
# 2 6 4
# 8 7 5
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 1106
# [7, 8, 1, 2, 3, 4, 6, 0, 5]
# Search for solution
#
# 7 8 1
# 2 3 4
# 6 0 5
# -->
# 7 8 1
# 2 3 4
# 0 6 5
# Cannot find solution
# Search time: 0.000988006591796875
# Number of initialized node: 1113
# [5, 0, 2, 7, 6, 3, 1, 4, 8]
# Search for solution
#
# 5 0 2
# 7 6 3
# 1 4 8
# -->
# 0 5 2
# 7 6 3
# 1 4 8
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 1120
# [7, 0, 1, 6, 2, 8, 4, 5, 3]
# Search for solution
#
# 7 0 1
# 6 2 8
# 4 5 3
# -->
# 7 2 1
# 6 0 8
# 4 5 3
# -->
# 7 2 1
# 6 5 8
# 4 0 3
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 1132
# [8, 7, 3, 0, 5, 4, 6, 2, 1]
# Search for solution
#
# 8 7 3
# 0 5 4
# 6 2 1
# -->
# 0 7 3
# 8 5 4
# 6 2 1
# -->
# 7 0 3
# 8 5 4
# 6 2 1
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 1142
# [6, 4, 8, 5, 7, 1, 3, 0, 2]
# Search for solution
#
# 6 4 8
# 5 7 1
# 3 0 2
# -->
# 6 4 8
# 5 0 1
# 3 7 2
# -->
# 6 0 8
# 5 4 1
# 3 7 2
# -->
# 0 6 8
# 5 4 1
# 3 7 2
# Cannot find solution
# Search time: 0.0010006427764892578
# Number of initialized node: 1156
# [4, 7, 6, 2, 0, 3, 5, 1, 8]
# Search for solution
#
# 4 7 6
# 2 0 3
# 5 1 8
# -->
# 4 0 6
# 2 7 3
# 5 1 8
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 1165
# [5, 4, 1, 0, 2, 6, 8, 3, 7]
# Search for solution
#
# 5 4 1
# 0 2 6
# 8 3 7
# -->
# 0 4 1
# 5 2 6
# 8 3 7
# -->
# 4 0 1
# 5 2 6
# 8 3 7
# -->
# 4 2 1
# 5 0 6
# 8 3 7
# -->
# 4 2 1
# 5 3 6
# 8 0 7
# -->
# 4 2 1
# 5 3 6
# 0 8 7
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 1184
# [7, 4, 8, 0, 2, 5, 3, 1, 6]
# Search for solution
#
# 7 4 8
# 0 2 5
# 3 1 6
# -->
# 0 4 8
# 7 2 5
# 3 1 6
# -->
# 4 0 8
# 7 2 5
# 3 1 6
# -->
# 4 2 8
# 7 0 5
# 3 1 6
# -->
# 4 2 8
# 7 1 5
# 3 0 6
# -->
# 4 2 8
# 7 1 5
# 0 3 6
# -->
# 4 2 8
# 0 1 5
# 7 3 6
# -->
# 0 2 8
# 4 1 5
# 7 3 6
# Cannot find solution
# Search time: 0.0009996891021728516
# Number of initialized node: 1208
# [3, 6, 5, 7, 0, 4, 8, 2, 1]
# Search for solution
#
# 3 6 5
# 7 0 4
# 8 2 1
# -->
# 3 0 5
# 7 6 4
# 8 2 1
# -->
# 0 3 5
# 7 6 4
# 8 2 1
# Cannot find solution
# Search time: 0.0010004043579101562
# Number of initialized node: 1219
# [7, 1, 3, 4, 2, 6, 8, 0, 5]
# Search for solution
#
# 7 1 3
# 4 2 6
# 8 0 5
# -->
# 7 1 3
# 4 2 6
# 0 8 5
# Cannot find solution
# Search time: 0.0009996891021728516
# Number of initialized node: 1226
# [3, 4, 6, 0, 5, 1, 7, 8, 2]
# Search for solution
#
# 3 4 6
# 0 5 1
# 7 8 2
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 1231
# [7, 1, 8, 2, 5, 4, 3, 6, 0]
# Search for solution
#
# 7 1 8
# 2 5 4
# 3 6 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 1235
# [4, 2, 1, 3, 5, 6, 7, 0, 8]
# Search for solution
#
# 4 2 1
# 3 5 6
# 7 0 8
# -->
# 4 2 1
# 3 5 6
# 7 8 0
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 1242
# [3, 6, 0, 8, 2, 7, 4, 5, 1]
# Search for solution
#
# 3 6 0
# 8 2 7
# 4 5 1
# -->
# 3 0 6
# 8 2 7
# 4 5 1
# -->
# 3 2 6
# 8 0 7
# 4 5 1
# -->
# 3 2 6
# 8 5 7
# 4 0 1
# -->
# 3 2 6
# 8 5 7
# 4 1 0
# Cannot find solution
# Search time: 0.0010018348693847656
# Number of initialized node: 1258
# [4, 0, 6, 2, 8, 7, 1, 3, 5]
# Search for solution
#
# 4 0 6
# 2 8 7
# 1 3 5
# Cannot find solution
# Search time: 0.0
# Number of initialized node: 1263

# %%
goal_state = [1,2,3,4,5,6,7,8,0]

check_solvability([1,2,3,4,5,0,7,8,6])
# Out:
# True

# %%
current_state = [1,2,3,4,5,0,7,8,6]

# %%
def h(current_state):
    """ Return the heuristic value for a given state. Default heuristic function used is 
    h(n) = number of misplaced tiles """

    return sum(s != g for (s, g) in zip(current_state, goal_state))

# %%
def actions(state):
    """ Return the actions that can be executed in the given state.
    The result would be a list, since there are only four possible actions
    in any given state of the environment """

    possible_actions = ['UP', 'DOWN', 'LEFT', 'RIGHT']
    index_blank_square = self.find_blank_square(state)

    if index_blank_square % 3 == 0:
        possible_actions.remove('LEFT')
    if index_blank_square < 3:
        possible_actions.remove('UP')
    if index_blank_square % 3 == 2:
        possible_actions.remove('RIGHT')
    if index_blank_square > 5:
        possible_actions.remove('DOWN')

    return possible_actions

# %%
def check_solvability(state):
    """ Checks if the given state is solvable """

    inversion = 0
    for i in range(len(state)):
        for j in range(i + 1, len(state)):
            if (state[i] > state[j]) and state[i] != 0 and state[j] != 0:
                inversion += 1

    return inversion % 2 == 0
